# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house=pd.read_csv("House_Price.csv")

# %%
house.head()
# Out:
#    Area_sqft  Bedrooms  Bathrooms  House_Age  Distance_City_km  Parking_Slots  \
# 0       1460         3          3         10                26              1
# 1       1894         3          2         16                 3              0
# 2       1730         1          2          7                 8              1
# 3       1695         3          1          3                14              2
# 4       2238         3          4          5                24              2
#
#    Floor  Price_Lakhs
# 0      6        64.52
# 1      3       110.46
# 2      9        83.00
# 3      4        76.91
# 4      1        98.69

# %%
house.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area_sqft         100 non-null    int64
#  1   Bedrooms          100 non-null    int64
#  2   Bathrooms         100 non-null    int64
#  3   House_Age         100 non-null    int64
#  4   Distance_City_km  100 non-null    int64
#  5   Parking_Slots     100 non-null    int64
#  6   Floor             100 non-null    int64
#  7   Price_Lakhs       100 non-null    float64
# dtypes: float64(1), int64(7)
# memory usage: 6.4 KB

# %%
house.tail()
# Out:
#     Area_sqft  Bedrooms  Bathrooms  House_Age  Distance_City_km  \
# 95       1967         2          2          2                28
# 96       1752         4          4         17                26
# 97       2627         5          1         24                23
# 98       3295         1          4          9                26
# 99       2095         1          4         21                 5
#
#     Parking_Slots  Floor  Price_Lakhs
# 95              1      9        93.64
# 96              1      9        81.81
# 97              1     11       142.41
# 98              2      0       157.84
# 99              0     12       100.78

# %%
bed=house['Bedrooms'].value_counts()
print(bed)
plt.figure()
bed.plot(kind='bar')
plt.title("Bedroom Count Distribution")
plt.show()
# Out:
# Bedrooms
# 1    27
# 3    23
# 4    20
# 5    16
# 2    14
# Name: count, dtype: int64
